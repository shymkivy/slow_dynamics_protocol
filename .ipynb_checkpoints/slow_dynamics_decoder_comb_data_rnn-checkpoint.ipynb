# %%
# ---- importing functions ----
import sys
import numpy as np

# importing slow dynamics pipeline
pipeline_dir = 'C:/Users/ys2605/Desktop/stuff/slow_dynamics_analysis'    # edit this  
sys.path.append(pipeline_dir + '/functions')
from f_sd_utils import f_load_caim_data_mat, f_load_rnn_test, f_get_values, f_get_frames, f_normalize, f_get_stim_trig_resp, f_plot_fig_raster, f_plot_fig_diag_decoder, f_plot_fig_full_decoder_caim, f_plot_fig_full_decoder_RNN, f_save_fig
from f_sd_decoder import f_run_binwise_dec, f_shuffle_trials
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 8
#       6 pipeline_dir = 'C:/Users/ys2605/Desktop/stuff/slow_dynamics_analysis'    # edit this
#       7 sys.path.append(pipeline_dir + '/functions')
# ----> 8 from f_sd_utils import f_load_caim_data_mat, f_load_rnn_test, f_get_values, f_get_frames, f_normalize, f_get_stim_trig_resp, f_plot_fig1_raster, f_plot_fig2_diag_decoder, f_plot_fig3_full_decoder_caim, f_plot_fig4_full_decoder_RNN, f_save_fig
#       9 from f_sd_decoder import f_run_binwise_dec, f_shuffle_trials
#
# ImportError: cannot import name 'f_plot_fig1_raster' from 'f_sd_utils' (C:\Users/ys2605/Desktop/stuff/slow_dynamics_analysis/functions\f_sd_utils.py)

# %%
# ---- Save figures as along the way ---- 
save_figs = False  # can turn on or off to save figures or not
fig_dir = 'C:/Users/ys2605/Desktop/stuff/papers/AC_paper_protocol/figures/python_decoder_comb'    # edit this

# %%
# ---- loading mismatch CaIm datasets ----
# for external datasets theses steps need to be modified
data_dir = 'F:/AC_data/caiman_data_missmatch/'   # edit this 
 
# loading raw firing rates, trial types, and stimuli times from oddball dataset
data_ob = f_load_caim_data_mat(
    data_dir,                            # data directory
    ext_list=['mat'],                    # data extension
    tags=['ammn', '_processed_data'],    # data tags
    num_files=20,                        # limit number of files to load
    deconvolution='oasis',               # deconvolution oasis or smoothdfdt
    smooth_std_duration=0.1)             # in sec

frame_rate = 1000/np.mean(f_get_values(data_ob, 'volume_period')) # in Hz; edit this for external datasets

# %%
# ---- loading RNN neuronal activity durung control inputs ----
# three types of RNNs trainings: odball recognition, control freq recognition, and untrained
# all three were tested with control inputs and neuronal activity was extracted
data_dir_rnn = 'F:/RNN_stuff/RNN_data/test_data/'
fname_rnn = 'test_data_2024_5_24_9h_42m'
data_rnn = f_load_rnn_test(
    data_dir_rnn, 
    fname_rnn + '_cont_data.npy',
    fname_rnn + '_params.npy',
    max_net_load = 5,
    flatten_runs = True,
    max_trial_types = 10,
    max_trials = 400,
    limit_network_types=['ob trained', 'freq trained'])     # ob trained, freq trained, untrained

frame_rate_rnn = 1000/np.mean(f_get_values(data_rnn, 'volume_period')) # in Hz; edit this for external datasets
training_type = np.array(f_get_values(data_rnn, 'training'))

# %%
# ---- plot example raster ----
fig = f_plot_fig_raster(
    data_ob[0]['firing_rates'][:,500:5000],
    f_normalize(data_rnn[0]['firing_rates'][:,2000:4500]),
    frame_rate=frame_rate,
    frame_rate_rnn=frame_rate_rnn)

# ---- save figure ----
if save_figs:    
    f_save_fig(fig, path=fig_dir, name_tag='Fig 1 Joint data rnn raster')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       1 # ---- plot example raster ----
#       2 fig = f_plot_fig1_raster(
#       3     data_ob[0]['firing_rates'][:,500:5000],
# ----> 4     f_normalize(data_rnn[0]['firing_rates'][:,2000:4500]),
#       5     frame_rate=frame_rate,
#       6     frame_rate_rnn=frame_rate_rnn)
#       8 # ---- save figure ----
#       9 if save_figs:
#
# NameError: name 'data_rnn' is not defined

# %%
# ---- CaIm data extracting trials using stimulus times ----
# compute trial window frames (assuming all datasets have similar frame rate)
trial_frames, plot_t = f_get_frames(
    trial_win=[-1,3],         # sec relative to stim onset (pre, post)
    frame_rate=frame_rate)

# extract stimulus triggered average matrix (neurons, frames, trials)
stim_trig_resp_all = []
for n_fl in range(len(data_ob)):  
    stim_trig_resp = f_get_stim_trig_resp(
        data_ob[n_fl]['firing_rates'],    # firing rates
        data_ob[n_fl]['stim_times'],      # stimulus onset frames
        trial_frames=trial_frames)        # frames to be extracted
    
    stim_trig_resp_all.append(stim_trig_resp)

# %%
# ---- RNN tested with control inputs ----
# RNN compute trial window frames for stim triggered ave
trial_frames_rnn, plot_t_rnn = f_get_frames(
    trial_win=[-1,5],         # sec relative to stim onset (pre, post)
    frame_rate=frame_rate_rnn)

# computing stimulus triggered average (neurons, frames, trials)
stim_trig_resp_all_rnn = []
for n_fl in range(len(data_rnn)):  
    stim_trig_resp = f_get_stim_trig_resp(
        data_rnn[n_fl]['firing_rates'],    # firing rates
        data_rnn[n_fl]['stim_times'],      # stimulus onset frames
        trial_frames=trial_frames_rnn)     # frames to be extracted
    
    stim_trig_resp_all_rnn.append(stim_trig_resp)

# %%
# ---- Define diagonal binwise decoder ----
def f_diag_decoder(stim_trig_resp, trial_types):
    X_all = [stim_trig_resp,
             stim_trig_resp]

    Y_all = [trial_types,
             f_shuffle_trials(trial_types)]   # shuffled version
    
    dec_data = f_run_binwise_dec(
        X_all,
        Y_all,
        train_test_method='diag',   # options: full, diag, train_at_stim, test_at_stim
        pca_var_frac=1,             # reduce data with pca
        num_cv=5,                   # cross validation
        normalize=False,
        add_noise_sigma=1e-5,       # for stability 
        get_train_coeffs=True)

    return dec_data

# %%
# ---- Run for all CaIm datasets ----
dec_data_all = []
for n_fl in range(len(data_ob)):
    print('Training dataset %d/%d' % (n_fl+1, len(stim_trig_resp_all)))

    trial_types = data_ob[n_fl]['trial_types']
    trial_types_use = trial_types<10     # select trials to use

    dec_data = f_diag_decoder(
        stim_trig_resp_all[n_fl][:,:,trial_types_use],
        trial_types[trial_types_use])

    dec_data_all.append(dec_data)
print('Done')
# Out:
# Training dataset 1/20
# Training dataset 2/20
# Training dataset 3/20
# Training dataset 4/20
# Training dataset 5/20
# Training dataset 6/20
# Training dataset 7/20
# Training dataset 8/20
# Training dataset 9/20
# Training dataset 10/20
# Training dataset 11/20
# Training dataset 12/20
# Training dataset 13/20
# Training dataset 14/20
# Training dataset 15/20
# Training dataset 16/20
# Training dataset 17/20
# Training dataset 18/20
# Training dataset 19/20
# Training dataset 20/20
# Done

# %%
# ---- Run for all RNN datasets ----
dec_data_all_rnn = []
for n_fl in range(len(data_rnn)):
    print('Training dataset %d/%d' % (n_fl+1, len(stim_trig_resp_all_rnn)))

    dec_data = f_diag_decoder(
        stim_trig_resp_all_rnn[n_fl],
        data_rnn[n_fl]['trial_types'])

    dec_data_all_rnn.append(dec_data)
    
print('Done')
# Out:
# Training dataset 1/10
# Training dataset 2/10
# Training dataset 3/10
# Training dataset 4/10
# Training dataset 5/10
# Training dataset 6/10
# Training dataset 7/10
# Training dataset 8/10
# Training dataset 9/10
# Training dataset 10/10
# Done

# %%
# ---- Plotting diagonal decoder results ----
fig_diag = f_plot_fig_diag_decoder(
    dec_data_all,
    dec_data_all_rnn,
    training_type,
    plot_t=plot_t,
    plot_t_rnn=plot_t_rnn)

# ---- save figure ----
if save_figs:    
    f_save_fig(fig_diag, path=fig_dir, name_tag='Fig 1 joint binwise decoder')

# %%
# ---- Define full decoding space binwise decoder ----
def f_full_decoder(stim_trig_resp, trial_types):
    X_all = [stim_trig_resp,
             stim_trig_resp]

    Y_all = [trial_types,
             f_shuffle_trials(trial_types)]   # shuffled version
    
    dec_data = f_run_binwise_dec(
        X_all,
        Y_all,
        train_test_method='full',   # options: full, diag, train_at_stim, test_at_stim
        pca_var_frac=1,             # reduce data with pca
        num_cv=5,                   # cross validation
        normalize=False,
        add_noise_sigma=1e-5,       # for stability 
        log=True)
    return dec_data

# %%
# ---- Run example CaIm dataset ---- 
n_fl = 0      # select dataset

trial_types = data_ob[n_fl]['trial_types']
trial_types_use = trial_types<10     # select trials to use

dec_data_full = f_full_decoder(
    stim_trig_resp_all[n_fl][:,:,trial_types_use],
    trial_types[trial_types_use])

print('Done')
# Out:
# dset 1 of 2; train bin 0/114
# dset 1 of 2; train bin 1/114
# dset 1 of 2; train bin 2/114
# dset 1 of 2; train bin 3/114
# dset 1 of 2; train bin 4/114
# dset 1 of 2; train bin 5/114
# dset 1 of 2; train bin 6/114
# dset 1 of 2; train bin 7/114
# dset 1 of 2; train bin 8/114
# dset 1 of 2; train bin 9/114
# dset 1 of 2; train bin 10/114
# dset 1 of 2; train bin 11/114
# dset 1 of 2; train bin 12/114
# dset 1 of 2; train bin 13/114
# dset 1 of 2; train bin 14/114
# dset 1 of 2; train bin 15/114
# dset 1 of 2; train bin 16/114
# dset 1 of 2; train bin 17/114
# dset 1 of 2; train bin 18/114
# dset 1 of 2; train bin 19/114
# dset 1 of 2; train bin 20/114
# dset 1 of 2; train bin 21/114
# dset 1 of 2; train bin 22/114
# dset 1 of 2; train bin 23/114
# dset 1 of 2; train bin 24/114
# dset 1 of 2; train bin 25/114
# dset 1 of 2; train bin 26/114
# dset 1 of 2; train bin 27/114
# dset 1 of 2; train bin 28/114
# dset 1 of 2; train bin 29/114
# dset 1 of 2; train bin 30/114
# dset 1 of 2; train bin 31/114
# dset 1 of 2; train bin 32/114
# dset 1 of 2; train bin 33/114
# dset 1 of 2; train bin 34/114
# dset 1 of 2; train bin 35/114
# dset 1 of 2; train bin 36/114
# dset 1 of 2; train bin 37/114
# dset 1 of 2; train bin 38/114
# dset 1 of 2; train bin 39/114
# dset 1 of 2; train bin 40/114
# dset 1 of 2; train bin 41/114
# dset 1 of 2; train bin 42/114
# dset 1 of 2; train bin 43/114
# dset 1 of 2; train bin 44/114
# dset 1 of 2; train bin 45/114
# dset 1 of 2; train bin 46/114
# dset 1 of 2; train bin 47/114
# dset 1 of 2; train bin 48/114
# dset 1 of 2; train bin 49/114
# dset 1 of 2; train bin 50/114
# dset 1 of 2; train bin 51/114
# dset 1 of 2; train bin 52/114
# dset 1 of 2; train bin 53/114
# dset 1 of 2; train bin 54/114
# dset 1 of 2; train bin 55/114
# dset 1 of 2; train bin 56/114
# dset 1 of 2; train bin 57/114
# dset 1 of 2; train bin 58/114
# dset 1 of 2; train bin 59/114
# dset 1 of 2; train bin 60/114
# dset 1 of 2; train bin 61/114
# dset 1 of 2; train bin 62/114
# dset 1 of 2; train bin 63/114
# dset 1 of 2; train bin 64/114
# dset 1 of 2; train bin 65/114
# dset 1 of 2; train bin 66/114
# dset 1 of 2; train bin 67/114
# dset 1 of 2; train bin 68/114
# dset 1 of 2; train bin 69/114
# dset 1 of 2; train bin 70/114
# dset 1 of 2; train bin 71/114
# dset 1 of 2; train bin 72/114
# dset 1 of 2; train bin 73/114
# dset 1 of 2; train bin 74/114
# dset 1 of 2; train bin 75/114
# dset 1 of 2; train bin 76/114
# dset 1 of 2; train bin 77/114
# dset 1 of 2; train bin 78/114
# dset 1 of 2; train bin 79/114
# dset 1 of 2; train bin 80/114
# dset 1 of 2; train bin 81/114
# dset 1 of 2; train bin 82/114
# dset 1 of 2; train bin 83/114
# dset 1 of 2; train bin 84/114
# dset 1 of 2; train bin 85/114
# dset 1 of 2; train bin 86/114
# dset 1 of 2; train bin 87/114
# dset 1 of 2; train bin 88/114
# dset 1 of 2; train bin 89/114
# dset 1 of 2; train bin 90/114
# dset 1 of 2; train bin 91/114
# dset 1 of 2; train bin 92/114
# dset 1 of 2; train bin 93/114
# dset 1 of 2; train bin 94/114
# dset 1 of 2; train bin 95/114
# dset 1 of 2; train bin 96/114
# dset 1 of 2; train bin 97/114
# dset 1 of 2; train bin 98/114
# dset 1 of 2; train bin 99/114
# dset 1 of 2; train bin 100/114
# dset 1 of 2; train bin 101/114
# dset 1 of 2; train bin 102/114
# dset 1 of 2; train bin 103/114
# dset 1 of 2; train bin 104/114
# dset 1 of 2; train bin 105/114
# dset 1 of 2; train bin 106/114
# dset 1 of 2; train bin 107/114
# dset 1 of 2; train bin 108/114
# dset 1 of 2; train bin 109/114
# dset 1 of 2; train bin 110/114
# dset 1 of 2; train bin 111/114
# dset 1 of 2; train bin 112/114
# dset 1 of 2; train bin 113/114
# dset 2 of 2; train bin 0/114
# dset 2 of 2; train bin 1/114
# dset 2 of 2; train bin 2/114
# dset 2 of 2; train bin 3/114
# dset 2 of 2; train bin 4/114
# dset 2 of 2; train bin 5/114
# dset 2 of 2; train bin 6/114
# dset 2 of 2; train bin 7/114
# dset 2 of 2; train bin 8/114
# dset 2 of 2; train bin 9/114
# dset 2 of 2; train bin 10/114
# dset 2 of 2; train bin 11/114
# dset 2 of 2; train bin 12/114
# dset 2 of 2; train bin 13/114
# dset 2 of 2; train bin 14/114
# dset 2 of 2; train bin 15/114
# dset 2 of 2; train bin 16/114
# dset 2 of 2; train bin 17/114
# dset 2 of 2; train bin 18/114
# dset 2 of 2; train bin 19/114
# dset 2 of 2; train bin 20/114
# dset 2 of 2; train bin 21/114
# dset 2 of 2; train bin 22/114
# dset 2 of 2; train bin 23/114
# dset 2 of 2; train bin 24/114
# dset 2 of 2; train bin 25/114
# dset 2 of 2; train bin 26/114
# dset 2 of 2; train bin 27/114
# dset 2 of 2; train bin 28/114
# dset 2 of 2; train bin 29/114
# dset 2 of 2; train bin 30/114
# dset 2 of 2; train bin 31/114
# dset 2 of 2; train bin 32/114
# dset 2 of 2; train bin 33/114
# dset 2 of 2; train bin 34/114
# dset 2 of 2; train bin 35/114
# dset 2 of 2; train bin 36/114
# dset 2 of 2; train bin 37/114
# dset 2 of 2; train bin 38/114
# dset 2 of 2; train bin 39/114
# dset 2 of 2; train bin 40/114
# dset 2 of 2; train bin 41/114
# dset 2 of 2; train bin 42/114
# dset 2 of 2; train bin 43/114
# dset 2 of 2; train bin 44/114
# dset 2 of 2; train bin 45/114
# dset 2 of 2; train bin 46/114
# dset 2 of 2; train bin 47/114
# dset 2 of 2; train bin 48/114
# dset 2 of 2; train bin 49/114
# dset 2 of 2; train bin 50/114
# dset 2 of 2; train bin 51/114
# dset 2 of 2; train bin 52/114
# dset 2 of 2; train bin 53/114
# dset 2 of 2; train bin 54/114
# dset 2 of 2; train bin 55/114
# dset 2 of 2; train bin 56/114
# dset 2 of 2; train bin 57/114
# dset 2 of 2; train bin 58/114
# dset 2 of 2; train bin 59/114
# dset 2 of 2; train bin 60/114
# dset 2 of 2; train bin 61/114
# dset 2 of 2; train bin 62/114
# dset 2 of 2; train bin 63/114
# dset 2 of 2; train bin 64/114
# dset 2 of 2; train bin 65/114
# dset 2 of 2; train bin 66/114
# dset 2 of 2; train bin 67/114
# dset 2 of 2; train bin 68/114
# dset 2 of 2; train bin 69/114
# dset 2 of 2; train bin 70/114
# dset 2 of 2; train bin 71/114
# dset 2 of 2; train bin 72/114
# dset 2 of 2; train bin 73/114
# dset 2 of 2; train bin 74/114
# dset 2 of 2; train bin 75/114
# dset 2 of 2; train bin 76/114
# dset 2 of 2; train bin 77/114
# dset 2 of 2; train bin 78/114
# dset 2 of 2; train bin 79/114
# dset 2 of 2; train bin 80/114
# dset 2 of 2; train bin 81/114
# dset 2 of 2; train bin 82/114
# dset 2 of 2; train bin 83/114
# dset 2 of 2; train bin 84/114
# dset 2 of 2; train bin 85/114
# dset 2 of 2; train bin 86/114
# dset 2 of 2; train bin 87/114
# dset 2 of 2; train bin 88/114
# dset 2 of 2; train bin 89/114
# dset 2 of 2; train bin 90/114
# dset 2 of 2; train bin 91/114
# dset 2 of 2; train bin 92/114
# dset 2 of 2; train bin 93/114
# dset 2 of 2; train bin 94/114
# dset 2 of 2; train bin 95/114
# dset 2 of 2; train bin 96/114
# dset 2 of 2; train bin 97/114
# dset 2 of 2; train bin 98/114
# dset 2 of 2; train bin 99/114
# dset 2 of 2; train bin 100/114
# dset 2 of 2; train bin 101/114
# dset 2 of 2; train bin 102/114
# dset 2 of 2; train bin 103/114
# dset 2 of 2; train bin 104/114
# dset 2 of 2; train bin 105/114
# dset 2 of 2; train bin 106/114
# dset 2 of 2; train bin 107/114
# dset 2 of 2; train bin 108/114
# dset 2 of 2; train bin 109/114
# dset 2 of 2; train bin 110/114
# dset 2 of 2; train bin 111/114
# dset 2 of 2; train bin 112/114
# dset 2 of 2; train bin 113/114
# done; 172.39 sec
# Done

# %%
# ---- Plotting full decoder results CaIm data ----
fig_full = f_plot_fig_full_decoder_caim(dec_data_full, plot_t)

if save_figs:
    f_save_fig(fig_full, path=fig_dir, name_tag='')

# %%
# ---- Run example RNN datasets ---- 
n_fl = np.where(training_type == 'ob trained')[0][0]
dec_data_full_ob = f_full_decoder(
    stim_trig_resp_all_rnn[n_fl],
    data_rnn[n_fl]['trial_types'])

n_fl = np.where(training_type == 'freq trained')[0][0]
dec_data_full_freq = f_full_decoder(
    stim_trig_resp_all_rnn[n_fl],
    data_rnn[n_fl]['trial_types'])

print('Done')
# Out:
# dset 1 of 2; train bin 0/120
# dset 1 of 2; train bin 1/120
# dset 1 of 2; train bin 2/120
# dset 1 of 2; train bin 3/120
# dset 1 of 2; train bin 4/120
# dset 1 of 2; train bin 5/120
# dset 1 of 2; train bin 6/120
# dset 1 of 2; train bin 7/120
# dset 1 of 2; train bin 8/120
# dset 1 of 2; train bin 9/120
# dset 1 of 2; train bin 10/120
# dset 1 of 2; train bin 11/120
# dset 1 of 2; train bin 12/120
# dset 1 of 2; train bin 13/120
# dset 1 of 2; train bin 14/120
# dset 1 of 2; train bin 15/120
# dset 1 of 2; train bin 16/120
# dset 1 of 2; train bin 17/120
# dset 1 of 2; train bin 18/120
# dset 1 of 2; train bin 19/120
# dset 1 of 2; train bin 20/120
# dset 1 of 2; train bin 21/120
# dset 1 of 2; train bin 22/120
# dset 1 of 2; train bin 23/120
# dset 1 of 2; train bin 24/120
# dset 1 of 2; train bin 25/120
# dset 1 of 2; train bin 26/120
# dset 1 of 2; train bin 27/120
# dset 1 of 2; train bin 28/120
# dset 1 of 2; train bin 29/120
# dset 1 of 2; train bin 30/120
# dset 1 of 2; train bin 31/120
# dset 1 of 2; train bin 32/120
# dset 1 of 2; train bin 33/120
# dset 1 of 2; train bin 34/120
# dset 1 of 2; train bin 35/120
# dset 1 of 2; train bin 36/120
# dset 1 of 2; train bin 37/120
# dset 1 of 2; train bin 38/120
# dset 1 of 2; train bin 39/120
# dset 1 of 2; train bin 40/120
# dset 1 of 2; train bin 41/120
# dset 1 of 2; train bin 42/120
# dset 1 of 2; train bin 43/120
# dset 1 of 2; train bin 44/120
# dset 1 of 2; train bin 45/120
# dset 1 of 2; train bin 46/120
# dset 1 of 2; train bin 47/120
# dset 1 of 2; train bin 48/120
# dset 1 of 2; train bin 49/120
# dset 1 of 2; train bin 50/120
# dset 1 of 2; train bin 51/120
# dset 1 of 2; train bin 52/120
# dset 1 of 2; train bin 53/120
# dset 1 of 2; train bin 54/120
# dset 1 of 2; train bin 55/120
# dset 1 of 2; train bin 56/120
# dset 1 of 2; train bin 57/120
# dset 1 of 2; train bin 58/120
# dset 1 of 2; train bin 59/120
# dset 1 of 2; train bin 60/120
# dset 1 of 2; train bin 61/120
# dset 1 of 2; train bin 62/120
# dset 1 of 2; train bin 63/120
# dset 1 of 2; train bin 64/120
# dset 1 of 2; train bin 65/120
# dset 1 of 2; train bin 66/120
# dset 1 of 2; train bin 67/120
# dset 1 of 2; train bin 68/120
# dset 1 of 2; train bin 69/120
# dset 1 of 2; train bin 70/120
# dset 1 of 2; train bin 71/120
# dset 1 of 2; train bin 72/120
# dset 1 of 2; train bin 73/120
# dset 1 of 2; train bin 74/120
# dset 1 of 2; train bin 75/120
# dset 1 of 2; train bin 76/120
# dset 1 of 2; train bin 77/120
# dset 1 of 2; train bin 78/120
# dset 1 of 2; train bin 79/120
# dset 1 of 2; train bin 80/120
# dset 1 of 2; train bin 81/120
# dset 1 of 2; train bin 82/120
# dset 1 of 2; train bin 83/120
# dset 1 of 2; train bin 84/120
# dset 1 of 2; train bin 85/120
# dset 1 of 2; train bin 86/120
# dset 1 of 2; train bin 87/120
# dset 1 of 2; train bin 88/120
# dset 1 of 2; train bin 89/120
# dset 1 of 2; train bin 90/120
# dset 1 of 2; train bin 91/120
# dset 1 of 2; train bin 92/120
# dset 1 of 2; train bin 93/120
# dset 1 of 2; train bin 94/120
# dset 1 of 2; train bin 95/120
# dset 1 of 2; train bin 96/120
# dset 1 of 2; train bin 97/120
# dset 1 of 2; train bin 98/120
# dset 1 of 2; train bin 99/120
# dset 1 of 2; train bin 100/120
# dset 1 of 2; train bin 101/120
# dset 1 of 2; train bin 102/120
# dset 1 of 2; train bin 103/120
# dset 1 of 2; train bin 104/120
# dset 1 of 2; train bin 105/120
# dset 1 of 2; train bin 106/120
# dset 1 of 2; train bin 107/120
# dset 1 of 2; train bin 108/120
# dset 1 of 2; train bin 109/120
# dset 1 of 2; train bin 110/120
# dset 1 of 2; train bin 111/120
# dset 1 of 2; train bin 112/120
# dset 1 of 2; train bin 113/120
# dset 1 of 2; train bin 114/120
# dset 1 of 2; train bin 115/120
# dset 1 of 2; train bin 116/120
# dset 1 of 2; train bin 117/120
# dset 1 of 2; train bin 118/120
# dset 1 of 2; train bin 119/120
# dset 2 of 2; train bin 0/120
# dset 2 of 2; train bin 1/120
# dset 2 of 2; train bin 2/120
# dset 2 of 2; train bin 3/120
# dset 2 of 2; train bin 4/120
# dset 2 of 2; train bin 5/120
# dset 2 of 2; train bin 6/120
# dset 2 of 2; train bin 7/120
# dset 2 of 2; train bin 8/120
# dset 2 of 2; train bin 9/120
# dset 2 of 2; train bin 10/120
# dset 2 of 2; train bin 11/120
# dset 2 of 2; train bin 12/120
# dset 2 of 2; train bin 13/120
# dset 2 of 2; train bin 14/120
# dset 2 of 2; train bin 15/120
# dset 2 of 2; train bin 16/120
# dset 2 of 2; train bin 17/120
# dset 2 of 2; train bin 18/120
# dset 2 of 2; train bin 19/120
# dset 2 of 2; train bin 20/120
# dset 2 of 2; train bin 21/120
# dset 2 of 2; train bin 22/120
# dset 2 of 2; train bin 23/120
# dset 2 of 2; train bin 24/120
# dset 2 of 2; train bin 25/120
# dset 2 of 2; train bin 26/120
# dset 2 of 2; train bin 27/120
# dset 2 of 2; train bin 28/120
# dset 2 of 2; train bin 29/120
# dset 2 of 2; train bin 30/120
# dset 2 of 2; train bin 31/120
# dset 2 of 2; train bin 32/120
# dset 2 of 2; train bin 33/120
# dset 2 of 2; train bin 34/120
# dset 2 of 2; train bin 35/120
# dset 2 of 2; train bin 36/120
# dset 2 of 2; train bin 37/120
# dset 2 of 2; train bin 38/120
# dset 2 of 2; train bin 39/120
# dset 2 of 2; train bin 40/120
# dset 2 of 2; train bin 41/120
# dset 2 of 2; train bin 42/120
# dset 2 of 2; train bin 43/120
# dset 2 of 2; train bin 44/120
# dset 2 of 2; train bin 45/120
# dset 2 of 2; train bin 46/120
# dset 2 of 2; train bin 47/120
# dset 2 of 2; train bin 48/120
# dset 2 of 2; train bin 49/120
# dset 2 of 2; train bin 50/120
# dset 2 of 2; train bin 51/120
# dset 2 of 2; train bin 52/120
# dset 2 of 2; train bin 53/120
# dset 2 of 2; train bin 54/120
# dset 2 of 2; train bin 55/120
# dset 2 of 2; train bin 56/120
# dset 2 of 2; train bin 57/120
# dset 2 of 2; train bin 58/120
# dset 2 of 2; train bin 59/120
# dset 2 of 2; train bin 60/120
# dset 2 of 2; train bin 61/120
# dset 2 of 2; train bin 62/120
# dset 2 of 2; train bin 63/120
# dset 2 of 2; train bin 64/120
# dset 2 of 2; train bin 65/120
# dset 2 of 2; train bin 66/120
# dset 2 of 2; train bin 67/120
# dset 2 of 2; train bin 68/120
# dset 2 of 2; train bin 69/120
# dset 2 of 2; train bin 70/120
# dset 2 of 2; train bin 71/120
# dset 2 of 2; train bin 72/120
# dset 2 of 2; train bin 73/120
# dset 2 of 2; train bin 74/120
# dset 2 of 2; train bin 75/120
# dset 2 of 2; train bin 76/120
# dset 2 of 2; train bin 77/120
# dset 2 of 2; train bin 78/120
# dset 2 of 2; train bin 79/120
# dset 2 of 2; train bin 80/120
# dset 2 of 2; train bin 81/120
# dset 2 of 2; train bin 82/120
# dset 2 of 2; train bin 83/120
# dset 2 of 2; train bin 84/120
# dset 2 of 2; train bin 85/120
# dset 2 of 2; train bin 86/120
# dset 2 of 2; train bin 87/120
# dset 2 of 2; train bin 88/120
# dset 2 of 2; train bin 89/120
# dset 2 of 2; train bin 90/120
# dset 2 of 2; train bin 91/120
# dset 2 of 2; train bin 92/120
# dset 2 of 2; train bin 93/120
# dset 2 of 2; train bin 94/120
# dset 2 of 2; train bin 95/120
# dset 2 of 2; train bin 96/120
# dset 2 of 2; train bin 97/120
# dset 2 of 2; train bin 98/120
# dset 2 of 2; train bin 99/120
# dset 2 of 2; train bin 100/120
# dset 2 of 2; train bin 101/120
# dset 2 of 2; train bin 102/120
# dset 2 of 2; train bin 103/120
# dset 2 of 2; train bin 104/120
# dset 2 of 2; train bin 105/120
# dset 2 of 2; train bin 106/120
# dset 2 of 2; train bin 107/120
# dset 2 of 2; train bin 108/120
# dset 2 of 2; train bin 109/120
# dset 2 of 2; train bin 110/120
# dset 2 of 2; train bin 111/120
# dset 2 of 2; train bin 112/120
# dset 2 of 2; train bin 113/120
# dset 2 of 2; train bin 114/120
# dset 2 of 2; train bin 115/120
# dset 2 of 2; train bin 116/120
# dset 2 of 2; train bin 117/120
# dset 2 of 2; train bin 118/120
# dset 2 of 2; train bin 119/120
# done; 211.17 sec
# dset 1 of 2; train bin 0/120
# dset 1 of 2; train bin 1/120
# dset 1 of 2; train bin 2/120
# dset 1 of 2; train bin 3/120
# dset 1 of 2; train bin 4/120
# dset 1 of 2; train bin 5/120
# dset 1 of 2; train bin 6/120
# dset 1 of 2; train bin 7/120
# dset 1 of 2; train bin 8/120
# dset 1 of 2; train bin 9/120
# dset 1 of 2; train bin 10/120
# dset 1 of 2; train bin 11/120
# dset 1 of 2; train bin 12/120
# dset 1 of 2; train bin 13/120
# dset 1 of 2; train bin 14/120
# dset 1 of 2; train bin 15/120
# dset 1 of 2; train bin 16/120
# dset 1 of 2; train bin 17/120
# dset 1 of 2; train bin 18/120
# dset 1 of 2; train bin 19/120
# dset 1 of 2; train bin 20/120
# dset 1 of 2; train bin 21/120
# dset 1 of 2; train bin 22/120
# dset 1 of 2; train bin 23/120
# dset 1 of 2; train bin 24/120
# dset 1 of 2; train bin 25/120
# dset 1 of 2; train bin 26/120
# dset 1 of 2; train bin 27/120
# dset 1 of 2; train bin 28/120
# dset 1 of 2; train bin 29/120
# dset 1 of 2; train bin 30/120
# dset 1 of 2; train bin 31/120
# dset 1 of 2; train bin 32/120
# dset 1 of 2; train bin 33/120
# dset 1 of 2; train bin 34/120
# dset 1 of 2; train bin 35/120
# dset 1 of 2; train bin 36/120
# dset 1 of 2; train bin 37/120
# dset 1 of 2; train bin 38/120
# dset 1 of 2; train bin 39/120
# dset 1 of 2; train bin 40/120
# dset 1 of 2; train bin 41/120
# dset 1 of 2; train bin 42/120
# dset 1 of 2; train bin 43/120
# dset 1 of 2; train bin 44/120
# dset 1 of 2; train bin 45/120
# dset 1 of 2; train bin 46/120
# dset 1 of 2; train bin 47/120
# dset 1 of 2; train bin 48/120
# dset 1 of 2; train bin 49/120
# dset 1 of 2; train bin 50/120
# dset 1 of 2; train bin 51/120
# dset 1 of 2; train bin 52/120
# dset 1 of 2; train bin 53/120
# dset 1 of 2; train bin 54/120
# dset 1 of 2; train bin 55/120
# dset 1 of 2; train bin 56/120
# dset 1 of 2; train bin 57/120
# dset 1 of 2; train bin 58/120
# dset 1 of 2; train bin 59/120
# dset 1 of 2; train bin 60/120
# dset 1 of 2; train bin 61/120
# dset 1 of 2; train bin 62/120
# dset 1 of 2; train bin 63/120
# dset 1 of 2; train bin 64/120
# dset 1 of 2; train bin 65/120
# dset 1 of 2; train bin 66/120
# dset 1 of 2; train bin 67/120
# dset 1 of 2; train bin 68/120
# dset 1 of 2; train bin 69/120
# dset 1 of 2; train bin 70/120
# dset 1 of 2; train bin 71/120
# dset 1 of 2; train bin 72/120
# dset 1 of 2; train bin 73/120
# dset 1 of 2; train bin 74/120
# dset 1 of 2; train bin 75/120
# dset 1 of 2; train bin 76/120
# dset 1 of 2; train bin 77/120
# dset 1 of 2; train bin 78/120
# dset 1 of 2; train bin 79/120
# dset 1 of 2; train bin 80/120
# dset 1 of 2; train bin 81/120
# dset 1 of 2; train bin 82/120
# dset 1 of 2; train bin 83/120
# dset 1 of 2; train bin 84/120
# dset 1 of 2; train bin 85/120
# dset 1 of 2; train bin 86/120
# dset 1 of 2; train bin 87/120
# dset 1 of 2; train bin 88/120
# dset 1 of 2; train bin 89/120
# dset 1 of 2; train bin 90/120
# dset 1 of 2; train bin 91/120
# dset 1 of 2; train bin 92/120
# dset 1 of 2; train bin 93/120
# dset 1 of 2; train bin 94/120
# dset 1 of 2; train bin 95/120
# dset 1 of 2; train bin 96/120
# dset 1 of 2; train bin 97/120
# dset 1 of 2; train bin 98/120
# dset 1 of 2; train bin 99/120
# dset 1 of 2; train bin 100/120
# dset 1 of 2; train bin 101/120
# dset 1 of 2; train bin 102/120
# dset 1 of 2; train bin 103/120
# dset 1 of 2; train bin 104/120
# dset 1 of 2; train bin 105/120
# dset 1 of 2; train bin 106/120
# dset 1 of 2; train bin 107/120
# dset 1 of 2; train bin 108/120
# dset 1 of 2; train bin 109/120
# dset 1 of 2; train bin 110/120
# dset 1 of 2; train bin 111/120
# dset 1 of 2; train bin 112/120
# dset 1 of 2; train bin 113/120
# dset 1 of 2; train bin 114/120
# dset 1 of 2; train bin 115/120
# dset 1 of 2; train bin 116/120
# dset 1 of 2; train bin 117/120
# dset 1 of 2; train bin 118/120
# dset 1 of 2; train bin 119/120
# dset 2 of 2; train bin 0/120
# dset 2 of 2; train bin 1/120
# dset 2 of 2; train bin 2/120
# dset 2 of 2; train bin 3/120
# dset 2 of 2; train bin 4/120
# dset 2 of 2; train bin 5/120
# dset 2 of 2; train bin 6/120
# dset 2 of 2; train bin 7/120
# dset 2 of 2; train bin 8/120
# dset 2 of 2; train bin 9/120
# dset 2 of 2; train bin 10/120
# dset 2 of 2; train bin 11/120
# dset 2 of 2; train bin 12/120
# dset 2 of 2; train bin 13/120
# dset 2 of 2; train bin 14/120
# dset 2 of 2; train bin 15/120
# dset 2 of 2; train bin 16/120
# dset 2 of 2; train bin 17/120
# dset 2 of 2; train bin 18/120
# dset 2 of 2; train bin 19/120
# dset 2 of 2; train bin 20/120
# dset 2 of 2; train bin 21/120
# dset 2 of 2; train bin 22/120
# dset 2 of 2; train bin 23/120
# dset 2 of 2; train bin 24/120
# dset 2 of 2; train bin 25/120
# dset 2 of 2; train bin 26/120
# dset 2 of 2; train bin 27/120
# dset 2 of 2; train bin 28/120
# dset 2 of 2; train bin 29/120
# dset 2 of 2; train bin 30/120
# dset 2 of 2; train bin 31/120
# dset 2 of 2; train bin 32/120
# dset 2 of 2; train bin 33/120
# dset 2 of 2; train bin 34/120
# dset 2 of 2; train bin 35/120
# dset 2 of 2; train bin 36/120
# dset 2 of 2; train bin 37/120
# dset 2 of 2; train bin 38/120
# dset 2 of 2; train bin 39/120
# dset 2 of 2; train bin 40/120
# dset 2 of 2; train bin 41/120
# dset 2 of 2; train bin 42/120
# dset 2 of 2; train bin 43/120
# dset 2 of 2; train bin 44/120
# dset 2 of 2; train bin 45/120
# dset 2 of 2; train bin 46/120
# dset 2 of 2; train bin 47/120
# dset 2 of 2; train bin 48/120
# dset 2 of 2; train bin 49/120
# dset 2 of 2; train bin 50/120
# dset 2 of 2; train bin 51/120
# dset 2 of 2; train bin 52/120
# dset 2 of 2; train bin 53/120
# dset 2 of 2; train bin 54/120
# dset 2 of 2; train bin 55/120
# dset 2 of 2; train bin 56/120
# dset 2 of 2; train bin 57/120
# dset 2 of 2; train bin 58/120
# dset 2 of 2; train bin 59/120
# dset 2 of 2; train bin 60/120
# dset 2 of 2; train bin 61/120
# dset 2 of 2; train bin 62/120
# dset 2 of 2; train bin 63/120
# dset 2 of 2; train bin 64/120
# dset 2 of 2; train bin 65/120
# dset 2 of 2; train bin 66/120
# dset 2 of 2; train bin 67/120
# dset 2 of 2; train bin 68/120
# dset 2 of 2; train bin 69/120
# dset 2 of 2; train bin 70/120
# dset 2 of 2; train bin 71/120
# dset 2 of 2; train bin 72/120
# dset 2 of 2; train bin 73/120
# dset 2 of 2; train bin 74/120
# dset 2 of 2; train bin 75/120
# dset 2 of 2; train bin 76/120
# dset 2 of 2; train bin 77/120
# dset 2 of 2; train bin 78/120
# dset 2 of 2; train bin 79/120
# dset 2 of 2; train bin 80/120
# dset 2 of 2; train bin 81/120
# dset 2 of 2; train bin 82/120
# dset 2 of 2; train bin 83/120
# dset 2 of 2; train bin 84/120
# dset 2 of 2; train bin 85/120
# dset 2 of 2; train bin 86/120
# dset 2 of 2; train bin 87/120
# dset 2 of 2; train bin 88/120
# dset 2 of 2; train bin 89/120
# dset 2 of 2; train bin 90/120
# dset 2 of 2; train bin 91/120
# dset 2 of 2; train bin 92/120
# dset 2 of 2; train bin 93/120
# dset 2 of 2; train bin 94/120
# dset 2 of 2; train bin 95/120
# dset 2 of 2; train bin 96/120
# dset 2 of 2; train bin 97/120
# dset 2 of 2; train bin 98/120
# dset 2 of 2; train bin 99/120
# dset 2 of 2; train bin 100/120
# dset 2 of 2; train bin 101/120
# dset 2 of 2; train bin 102/120
# dset 2 of 2; train bin 103/120
# dset 2 of 2; train bin 104/120
# dset 2 of 2; train bin 105/120
# dset 2 of 2; train bin 106/120
# dset 2 of 2; train bin 107/120
# dset 2 of 2; train bin 108/120
# dset 2 of 2; train bin 109/120
# dset 2 of 2; train bin 110/120
# dset 2 of 2; train bin 111/120
# dset 2 of 2; train bin 112/120
# dset 2 of 2; train bin 113/120
# dset 2 of 2; train bin 114/120
# dset 2 of 2; train bin 115/120
# dset 2 of 2; train bin 116/120
# dset 2 of 2; train bin 117/120
# dset 2 of 2; train bin 118/120
# dset 2 of 2; train bin 119/120
# done; 294.48 sec
# Done

# %%
# ---- Plotting full decoder results RNN data ----
fig_full = f_plot_fig_full_decoder_RNN(
    dec_data_full_ob,
    dec_data_full_freq,
    plot_t_rnn)

if save_figs:
    f_save_fig(fig_full, path=fig_dir, name_tag='')
